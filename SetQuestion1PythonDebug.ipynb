# %%
#1.Find the error in the following Python code:
# Ans=>: was missing
for i in range(5):
     print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code? Ans => Given print statement to print number and string 

a = 10
b = 5
print(a + b)
# Out:
# 15

# %%
#3.What is the issue in this Python snippet? Ans=> : was missing and Assignd values for paramete arguments with variable and print it
def add_numbers(a, b):
    return a + b

# %%
val=add_numbers(5, 7)
print(val)
# Out:
# 12

# %%
#4.Identify the bug in the following Python code: Ans => we tried to get the array index value which is not present . Here array lenth is 3 (0-3)
numbers = [1, 2, 3, 4]
print(numbers[3])
# Out:
# 4

# %%
#5.Find the error in the following Python code: Ans=> Parantheses was missed in print function
print ("Hello, World!")
# Out:
# Hello, World!

# %%
#6.Find the error in the following Python code: Ans=> Any value division by zero it will throw error 
x = 5 / 1
print(x)
# Out:
# 5.0

# %%
#7.Find the error in the following Python code:name = "Alice" : Ans => name value not given and we cannot concatenate string and interger 
age=25
name='Alice'
print("Name: ",name ,", Age: ",age)
# Out:
# Name:  Alice , Age:  25

# %%
#8.Find the error : Ans => -1 range will not taken in Range n parameter
for i in range(1, 10, 1):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
#9. Find the error in the following Python code: Ans=>If condition should == double equal and we should handle the else part as well 
x = 10
if x == 5:
    print("x is 5")
else :
    print(" x value is =",x)
# Out:
#  x value is = 10

# %%
#10. Identify the error in the following function definition:
def greet(name):
    print("Hello, " + name)

# %%
greet('Sankar!!')
# Out:
# Hello, Sankar!!
