# %%
#1.Find the error in the following Python code: ANS=> Python is case sensitive 
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
#2.Find the error in the following Python code: ANS=> Use the Gloabl variable 

def my_function():
    global x
    x += 5
    print(x)

x = 10
my_function()
# Out:
# 15

# %%
#3.ANS => Give == for 
x = 5
if x == 10:
    print("x is 10")
else:
   print("x is",x)
# Out:
# x is 5

# %%
#4.ANS => Sort will retun the none . DO the sort sepratedly and print the list
numbers = [5, 3, 8, 2]
numbers.sort()
print(numbers)
# Out:
# [2, 3, 5, 8]

# %%
#5. ANS => Either function print values or return the values 
def square(n):
    return n * n

print(square(4))
# Out:
# 16

# %%
#6.ANS => Tuples are Immutable not able to assing values 
my_tuple = (1, 2, 3)
#my_tuple[1] = 5
modified_tuple=(1,5,7)
print(modified_tuple)
# Out:
# (1, 5, 7)

# %%
#7.ANS => %S string and % d numner place holder 
name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name, age))
# Out:
# My name is Alice and I am 25 years old

# %%
#8.ANS=> IS not eqaul operator . we should use == for comparison
a = [1, 2, 3]
b = [1, 2, 3]
if a == b:
    print("Lists are equal")
else:
    print("List are not equal")
# Out:
# Lists are equal

# %%
#9.ANS => 1 parameter indicgtes start position and 2 paatmeter is stop posistion and third ia indicator
for i in range(1,5,1):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
#10. We should use sting in the key parameter
student = {"name": "John", "age": 20}
print(student["name"])
# Out:
# John
